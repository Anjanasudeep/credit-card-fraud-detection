# %% [markdown]
# <a href="https://colab.research.google.com/github/Anjanasudeep/credit-card-fraud-detection/blob/main/credit_card_fraud_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-fb89d6c6-0a17-46e0-a03f-653c31eb9d85" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fb89d6c6-0a17-46e0-a03f-653c31eb9d85">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data=pd.read_excel(r"new credit card.xlsx")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Time         5 non-null      int64
#  1   class        5 non-null      int64
#  2   v10          5 non-null      float64
#  3   v11          5 non-null      object
#  4   v12          5 non-null      float64
#  5   v13          5 non-null      float64
#  6   v14          5 non-null      object
#  7   v15          5 non-null      float64
#  8   v16          5 non-null      object
#  9   v17          5 non-null      float64
#  10  v18          5 non-null      object
#  11  Unnamed: 11  5 non-null      object
#  12  v19          5 non-null      float64
#  13  v20          5 non-null      float64
#  14  v21          5 non-null      object
#  15  v22          5 non-null      float64
#  16  v23          5 non-null      float64
#  17  v24          5 non-null      object
# ...

# %%
df.describe()
# Out:
#            Time    class       v10       v12       v13       v15       v17  \
# count  5.000000  5.00000  5.000000  5.000000  5.000000  5.000000  5.000000
# mean   2.000000  0.80000 -0.730162  1.563549  0.349166  0.704730  0.107676
# std    1.581139  0.83666  1.086764  0.865298  0.797262  0.797477  0.242901
# min    0.000000  0.00000 -1.359807  0.166480 -0.863291 -0.082361 -0.270533
# 25%    1.000000  0.00000 -1.358354  1.548718  0.379780  0.095921  0.085102
# 50%    2.000000  1.00000 -1.158233  1.773209  0.403034  0.462388  0.098698
# 75%    3.000000  1.00000 -0.966272  1.792993  0.448154  1.247203  0.247676
# max    4.000000  2.00000  1.191857  2.536347  1.378155  1.800499  0.377436
#
#             v19       v20       v22       v23       v25       v26
# count  5.000000  5.000000  5.000000  5.000000  5.000000  5.000000
# mean  -0.022763  0.242879 -0.399301  0.081887  0.070273  0.042106
# std    0.174671  0.596429  0.547679  0.380732  0.109967  0.106576
# ...

# %%
df.isnull()
# Out:
#     Time  class    v10    v11    v12    v13    v14    v15    v16    v17  ...  \
# 0  False  False  False  False  False  False  False  False  False  False  ...
# 1  False  False  False  False  False  False  False  False  False  False  ...
# 2  False  False  False  False  False  False  False  False  False  False  ...
# 3  False  False  False  False  False  False  False  False  False  False  ...
# 4  False  False  False  False  False  False  False  False  False  False  ...
#
#    Unnamed: 11    v19    v20    v21    v22    v23    v24    v25    v26  amount
# 0        False  False  False  False  False  False  False  False  False   False
# 1        False  False  False  False  False  False  False  False  False   False
# 2        False  False  False  False  False  False  False  False  False   False
# 3        False  False  False  False  False  False  False  False  False   False
# 4        False  False  False  False  False  False  False  False  False   False
#
# [5 rows x 21 columns]

# %%
df.isnull().sum()
# Out:
# Time           0
# class          0
# v10            0
# v11            0
# v12            0
# v13            0
# v14            0
# v15            0
# v16            0
# v17            0
# v18            0
# Unnamed: 11    0
# v19            0
# v20            0
# v21            0
# v22            0
# v23            0
# v24            0
# v25            0
# v26            0
# amount         0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates()
# Out:
#    Time  class       v10       v11       v12       v13       v14       v15  \
# 0     0      0 -1.359807 -0.072781  2.536347  1.378155       naN  0.462388
# 1     1      0  1.191857       naN  0.166480  0.448154  0.060018 -0.082361
# 2     2      1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3     3      1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4     4      2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
#
#         v16       v17  ... Unnamed: 11       v19       v20       v21  \
# 0  0.239599  0.098698  ...         ... -0.018307  0.277838 -0.110474
# 1 -0.078803  0.085102  ...         ... -0.225775 -0.638672  0.101288
# 2  0.791461  0.247676  ...         ...  0.247998  0.771679       naN
# 3  0.237609  0.377436  ...         ... -0.108300  0.005274 -0.190321
# 4       naN -0.270533  ...         ... -0.009431  0.798278 -0.137458
#
#         v22       v23       v24       v25       v26  amount
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.fillna("no record")
# Out:
#    Time  class       v10       v11       v12       v13       v14       v15  \
# 0     0      0 -1.359807 -0.072781  2.536347  1.378155       naN  0.462388
# 1     1      0  1.191857       naN  0.166480  0.448154  0.060018 -0.082361
# 2     2      1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3     3      1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4     4      2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
#
#         v16       v17  ... Unnamed: 11       v19       v20       v21  \
# 0  0.239599  0.098698  ...         ... -0.018307  0.277838 -0.110474
# 1 -0.078803  0.085102  ...         ... -0.225775 -0.638672  0.101288
# 2  0.791461  0.247676  ...         ...  0.247998  0.771679       naN
# 3  0.237609  0.377436  ...         ... -0.108300  0.005274 -0.190321
# 4       naN -0.270533  ...         ... -0.009431  0.798278 -0.137458
#
#         v22       v23       v24       v25       v26  amount
# ...

# %%
avg=df['Time'].mean()

# %%
import matplotlib.pyplot as plt
plt.scatter(df['Time'],df['amount'])
plt.title('Scatter Plot')
plt.xlabel('Time')
plt.ylabel('Amount')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot(df['Time'],df['amount'])
plt.title('Line Plot')
plt.xlabel('Time')
plt.ylabel('Amount')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Convert 'amount' to numeric, coercing errors to NaN
df['amount'] = pd.to_numeric(df['amount'], errors='coerce')

# Fill NaN values with 0 for the pie chart
df['amount'] = df['amount'].fillna(0)

plt.pie(df['amount'],labels=df['Time'])
plt.title('Pie Chart')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.hist(df['amount'])
plt.title('Histogram')
plt.xlabel('Amount')
plt.ylabel('Frequency')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
plt.suptitle('Subplots')
plt.subplot(2,2,1)
plt.scatter(df['Time'],df['amount'])
plt.title('Scatter Plot')
plt.xlabel('Time')
plt.ylabel('Amount')
plt.subplot(2,2,2)
plt.plot(df['Time'],df['amount'])
plt.title('Line Plot')
plt.xlabel('Time')
plt.ylabel('Amount')
plt.subplot(2,2,3)
plt.hist(df['amount'])
plt.title('Histogram')
plt.xlabel('Amount')
plt.ylabel('Frequency')
plt.subplot(2,2,4)
plt.pie(df['amount'],labels=df['Time'])
plt.title('Pie Chart')
plt.savefig("new_credit_card.png")
plt.show()

# %%
files.download("new_credit_card.png")
